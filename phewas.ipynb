# %%
#!pip install PheTK --upgrade

# %%
import inspect, phewas_plot, os
print(os.path.abspath(inspect.getfile(phewas_plot)))

import importlib, phewas_plot
importlib.reload(phewas_plot)
from phewas_plot import Plot
# Out:
# /Users/sy/Documents/Studies/0.Broad/03.variant_based/00.local/AoU/phewas/phewas_plot.py

# %%
from phewas_plot import Plot, set_global_font_size
set_global_font_size(14)

p = Plot("rs2925979_phewas_plus_plots_20250622/rs2925979_phewas_results.csv")

p.manhattan(fig_width=12, fig_height=4,
            axis_text_size=14, title_text_size=18,
            label_size=10, label_count=15,
            output_file_name="demo_manhattan.pdf")
# Out:
# Plot saved ➜ /Users/sy/Documents/Studies/0.Broad/03.variant_based/00.local/AoU/phewas/demo_manhattan.pdf
